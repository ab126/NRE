# %%
import os
import sys
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import numpy.random as nr
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import scipy
import pickle

cur_dir = os.getcwd()
path = Path(cur_dir)
sys.path.insert(0, str(path.parent.absolute()))


from src.nre.safe_routing import*
from src.nre.preprocess import preprocess_df
from src.nre.network_connectivity import ConnectivityUnit

# %%
seed = 232# 232
np.random.seed(seed)

n_max = 8
mu_all = nr.rand(n_max)#np.zeros(n_max)  # nr.rand(n_max)
A_all = nr.rand(n_max, n_max)
cov_all = np.dot(A_all, A_all.T)

ax1 = plt.subplot(121)
mat1 = ax1.matshow(mu_all.reshape((-1, 1)))
plt.colorbar(mat1)
ax1.set_xticks([], [])
ax2 = plt.subplot(122)
mat2 = ax2.matshow(cov_all)
plt.colorbar(mat2)

# %%
res_df = pd.DataFrame()
all_true_mean = []
n_dims = list(np.arange(3, n_max, 1))
for n_dim in n_dims:
    print(n_dim)
    mu = mu_all[:n_dim]
    cov = cov_all[:n_dim, :n_dim]
    #temp_df = naive_mc_max(mu, cov, 10000, 10)
    temp_df['n_dim'] = n_dim
    res_df = pd.concat((res_df, temp_df))
    all_true_mean.append(calc_mean_max(cov, mu))
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
import time

n_max = 8
mu_all = nr.rand(n_max)#np.zeros(n_max)  # nr.rand(n_max)
A_all = nr.rand(n_max, n_max)
cov_all = np.dot(A_all, A_all.T)
n_dim = 8

mu = mu_all[:n_dim]
cov = cov_all[:n_dim, :n_dim]

start = time.time()
calc_mean_max(cov, mu)
#temp_df = naive_mc_max(mu, cov, 10000, 10)
end = time.time()
print(end - start)
# Out:
# 73.90212535858154

# %%
sns.lineplot(data=res_df, x='n_dim', y='max', label='Monte Carlo')
plt.plot(n_dims, all_true_mean, label='Afonja (1972)')
plt.ylabel(r'$E[Y]$')
plt.xticks([i for i in n_dims], [i for i in n_dims])
plt.legend()

# %%
all_true_mean
# Out:
# [0.9342835750223697,
#  1.1077661470152813,
#  1.1778591546398856,
#  1.2668770677049193,
#  1.3640323919068835]

# %% [markdown]
# # Simple Safe Routing on CIC-IDS-2017

# %%
file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Tuesday-WorkingHours.pcap_ISCX.csv' 
df_cic = pd.read_csv(file_addr, header=0, encoding='cp1252')
df = preprocess_df(df_cic, date_col=' Timestamp')

# %%
with open(r'saves\victim_net.pickle', 'rb') as handle:
   entity_names = pickle.load(handle)

# %%
with open(r'saves\monday_freq_1000.pickle', 'rb') as handle:
   entity_names = pickle.load(handle)

# %%
with open(r'saves\monday_759.pickle', 'rb') as handle:
   entity_names = pickle.load(handle)

# %%
with open(r'saves\partitioned_nodes_141.pickle', 'rb') as handle:
   entity_names = pickle.load(handle)

# %%
len(entity_names)
# Out:
# 13

# %%
g = communication_graph_from_df(df, entity_names, keep_outsiders=False)
entity_names = list(g.nodes)
len(g), len(entity_names)
# Out:
# (13, 13)

# %%
len(entity_names), len(g)
# Out:
# (13, 13)

# %%
pos = nx.spring_layout(g)
nx.draw(g, pos=pos, with_labels=False)

# %%
import importlib, src, src.nre.analyze_cic_ids

importlib.reload(src.nre.analyze_cic_ids)
# 224
# Current time and samples shape:  2017-04-07 12:19:00 (75, 13)
# 225
# Current time and samples shape:  2017-04-07 12:21:00 (75, 13)
# 226
# Current time and samples shape:  2017-04-07 12:23:00 (75, 13)
# 227
# Current time and samples shape:  2017-04-07 12:25:00 (75, 13)
# 228
# Current time and samples shape:  2017-04-07 12:27:00 (75, 13)
# 229
# Current time and samples shape:  2017-04-07 12:29:00 (75, 13)
# 230
# Current time and samples shape:  2017-04-07 12:31:00 (75, 13)
# 231
# Current time and samples shape:  2017-04-07 12:33:00 (75, 13)
# 232
# Current time and samples shape:  2017-04-07 12:35:00 (75, 13)
# 233
# Current time and samples shape:  2017-04-07 12:37:00 (75, 13)
# 234
# Current time and samples shape:  2017-04-07 12:39:00 (75, 13)
# 235
# Current time and samples shape:  2017-04-07 12:41:00 (75, 13)
# 236
# Current time and samples shape:  2017-04-07 12:43:00 (75, 13)
# 237
# Current time and samples shape:  2017-04-07 12:45:00 (75, 13)
# 238
# Current time and samples shape:  2017-04-07 12:47:00 (75, 13)
# 239
# Current time and samples shape:  2017-04-07 12:49:00 (75, 13)
# 240
# Current time and samples shape:  2017-04-07 12:51:00 (75, 13)
# 241
# Current time and samples shape:  2017-04-07 12:53:00 (75, 13)
# 242
# Current time and samples shape:  2017-04-07 12:55:00 (75, 13)
# 243
# Current time and samples shape:  2017-04-07 12:57:00 (75, 13)
# 244
# Current time and samples shape:  2017-04-07 12:59:00 (75, 13)

# %%
with open(r'saves\risks_13.pickle', 'rb') as handle:
    risk_mean, risk_cov = pickle.load(handle)

# %%
src = '192.168.10.14' # 15
g = communication_graph_from_df(df.iloc[:,:], entity_names, keep_outsiders=False)
g.remove_node('192.168.10.3')
risk_dict = {node:risk for node, risk in zip(g.nodes, risk_mean)}

minmax_paths = {node:[source] for node in g.nodes}
distances = safest_path(g, src, risk_dict, path=minmax_paths)
# Out:
# C:\Users\bayer\PycharmProjects\NRE\src\nre\safe_routing.py:109: UserWarning: Multi-safest-paths are not added to variable path!
#   warnings.warn('Multi-safest-paths are not added to variable path!')

# %%
risk_dict
# Out:
# {'192.168.10.50': 0.3226571677826207,
#  '192.168.10.51': 0.3147361019517599,
#  '192.168.10.19': 0.3145493233597461,
#  '192.168.10.17': 0.09726828372447156,
#  '192.168.10.16': 0.30667782803766264,
#  '192.168.10.12': 0.27361689063073663,
#  '192.168.10.9': 0.2555874311167787,
#  '192.168.10.5': 0.26267371259017686,
#  '192.168.10.8': 0.2994053549778183,
#  '192.168.10.14': 0.2501097166405564,
#  '192.168.10.15': 0.2312205279546448,
#  '192.168.10.25': 0.26287066613855375}

# %%
distances
# Out:
# {'192.168.10.14': 0.2501097166405564,
#  '192.168.10.12': 0.27361689063073663,
#  '192.168.10.16': 0.30667782803766264,
#  '192.168.10.19': 0.3145493233597461,
#  '192.168.10.5': 0.3145493233597461,
#  '192.168.10.50': 0.3226571677826207,
#  '192.168.10.51': 0.3226571677826207,
#  '192.168.10.8': 0.3226571677826207,
#  '192.168.10.25': 0.3226571677826207,
#  '192.168.10.17': 0.3226571677826207,
#  '192.168.10.15': 0.3226571677826207,
#  '192.168.10.9': 0.3226571677826207}

# %%
# Replace nodes for visual
repr_node = '192.168.10.8'  # 25
temp = {}
for node in distances:
    if node == '192.168.10.50':
        temp[repr_node] = distances[repr_node]
    elif node == repr_node:
        temp['192.168.10.50'] = distances['192.168.10.50']
    else:
        temp[node] = distances[node]
distances = temp

# %% [markdown]
# # Safe Routing Plots

# %%
import importlib, src, src.nre.network_plotting

importlib.reload(src.nre.network_plotting)
from src.nre.network_plotting import*

# %%
import importlib, src

importlib.reload(src.nre.safe_routing)
from src.nre.safe_routing import*

# %%
source, paths
# Out:
# ('192.168.10.14',
#  {'192.168.10.50': ['192.168.10.14', '192.168.10.50'],
#   '192.168.10.51': ['192.168.10.14', '192.168.10.50', '192.168.10.51'],
#   '192.168.10.19': ['192.168.10.14', '192.168.10.19'],
#   '192.168.10.17': ['192.168.10.14', '192.168.10.50', '192.168.10.17'],
#   '192.168.10.16': ['192.168.10.14', '192.168.10.16'],
#   '192.168.10.12': ['192.168.10.14', '192.168.10.12'],
#   '192.168.10.9': ['192.168.10.14', '192.168.10.50', '192.168.10.9'],
#   '192.168.10.5': ['192.168.10.14', '192.168.10.19', '192.168.10.5'],
#   '192.168.10.8': ['192.168.10.14', '192.168.10.50', '192.168.10.8'],
#   '192.168.10.14': ['192.168.10.14'],
#   '192.168.10.15': ['192.168.10.14', '192.168.10.50', '192.168.10.15'],
#   '192.168.10.25': ['192.168.10.14', '192.168.10.50', '192.168.10.25']})

# %%
dst = '192.168.10.5'
shortest_path = ['192.168.10.14', '192.168.10.50', '192.168.10.5'] # nx.shortest_path(g, source, dst)
calc_risk_of_path(g, paths[dst], risk_dict), calc_risk_of_path(g, shortest_path, risk_dict)
# Out:
# (0.3145493233597461, 0.3226571677826207)

# %%
def_risk = calc_risk_of_path(g, shortest_path, risk_dict)
minmax_risk = calc_risk_of_path(g, paths[dst], risk_dict)
perc_gain = (def_risk - minmax_risk ) / def_risk
print("Percent gain {:.2f}".format(perc_gain))
# Out:
# Percent gain 0.03

# %%
risk_dict
# Out:
# {'192.168.10.50': 0.3226571677826207,
#  '192.168.10.51': 0.3147361019517599,
#  '192.168.10.19': 0.3145493233597461,
#  '192.168.10.17': 0.09726828372447156,
#  '192.168.10.16': 0.30667782803766264,
#  '192.168.10.12': 0.27361689063073663,
#  '192.168.10.9': 0.2555874311167787,
#  '192.168.10.5': 0.26267371259017686,
#  '192.168.10.8': 0.2994053549778183,
#  '192.168.10.14': 0.2501097166405564,
#  '192.168.10.15': 0.2312205279546448,
#  '192.168.10.25': 0.26287066613855375}

# %%
paths_highlight=[[('192.168.10.14', '192.168.10.19'), ('192.168.10.19', '192.168.10.5')],
                 [('192.168.10.14', '192.168.10.12'), ('192.168.10.12', '192.168.10.50'), 
                  ('192.168.10.50', '192.168.10.5')]]


fig = cartesian_dist_plot(g, distances, risk_dict, title='', show_names=True, label_size = 8,
                          destination='192.168.10.5', paths_highlight=paths_highlight, discrete_color=True)
# Out:
# C:\Users\bayer\PycharmProjects\NRE\venv2\lib\site-packages\networkx\drawing\nx_pylab.py:450: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   node_collection = ax.scatter(

# %%
fig = polar_dist_plot(g, distances, risk_dict, '', seed=19) # 95

# %% [markdown]
# # MCMC

# %%
temp_df = naive_mc_max(risk_mean.reshape((-1,)), risk_cov, 10000, 10)
sns.boxplot(data=temp_df, y='max')
# Out:
# <Axes: ylabel='max'>

# %%
import sampyl.samplers as smp

logp = lambda x: -x if x > 0 else -np.inf
metro = smp.Metropolis(logp, {'x': 1})
samps = metro.sample(1000)
samps.shape
plt.hist(samps.x, density= True)
plt.plot(np.exp(-np.arange(7)))
# Out:
# Progress: [##############################] 1000 of 1000 samples

# %% [markdown]
# # Miscellaneous Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(1, 10, 0.01)

plt.rcParams.update({'font.size': 24})
plt.plot(x_axis, norm.pdf(x_axis, 5, 0.5))
plt.xlabel(r'$x$')
plt.ylabel(r'$f_X(x)$')
# Out:
# Text(0, 0.5, '$f_X(x)$')

# %%
seed = 232
np.random.seed(seed)

n = 2

mu = np.array([-.2,-.2])
cov = np.array([[1, 0.5],
                [0.5, 0.5]])

ax1 = plt.subplot(121)
mat1 = ax1.matshow(mu.reshape((-1, 1)))
plt.colorbar(mat1)
ax2 = plt.subplot(122)
mat2 = ax2.matshow(cov)
plt.colorbar(mat2)

# %%
from scipy.stats import multivariate_normal

rv = multivariate_normal(mean= mu, cov= cov, allow_singular=False)

y_min, y_max = -2, 2
x_min, x_max = -2.5, 2.5
eps = 0.15

x, y = np.mgrid[x_min:x_max:.01, y_min:y_max:.01]
pos = np.dstack((x, y))
fig = plt.figure()
ax = fig.add_subplot(111)
ax.contourf(x, y, rv.pdf(pos), alpha= 0.9, cmap='Blues')
ax.set_xlabel(r'$x_1$')
ax.set_ylabel(r'$x_2$')
#fig.savefig(fname='./figures/mvn.jpg')

y_val = 0.7
ax.plot([y_val, y_val], [y_min, y_val], color= 'k', alpha= 0.5)#, linestyle='dashed'
ax.plot([x_min, y_val], [y_val, y_val], color= 'k', alpha= 0.5)
ax.set_xticks([y_val], ['y'])
ax.set_yticks([y_val], ['y'])
ax.fill_between([x_min, y_val], [y_min, y_min], [y_val, y_val], color='tab:blue', alpha=0.3)
fig.savefig(fname='./figures/mvn_y.jpg')

ax.plot([y_val, y_val], [y_val, y_val+eps], color= 'k', alpha= 0.5, linestyle='dashed')
ax.plot([y_val, y_val+eps], [y_val, y_val], color= 'k', alpha= 0.5, linestyle='dashed')
ax.plot([y_val+eps, y_val+eps], [y_min, y_val+eps], color= 'k', alpha= 0.5, linestyle='dashed')
ax.plot([x_min, y_val+eps], [y_val+eps, y_val+eps], color= 'k', alpha= 0.5, linestyle='dashed')
ax.set_xticks([y_val, y_val+eps], ['y', 'y+dy'], rotation= 45)
ax.set_yticks([y_val, y_val+eps], ['y', 'y+dy'])
#fig.savefig(fname='./figures/mvn_y_dy.jpg')

ax.fill_between([x_min, y_val], [y_min, y_min], [y_val, y_val], color='tab:blue', alpha=0.3)
ax.fill_between([x_min, y_val], [y_val, y_val], [y_val+eps, y_val+eps], color='tab:green', alpha=0.3)
ax.fill_between([y_val, y_val+eps], [y_min, y_min], [y_val, y_val], color='tab:green', alpha=0.3)
ax.fill_between([y_val, y_val+eps], [y_val, y_val], [y_val+eps, y_val+eps], color='tab:red', alpha=0.3)
#fig.savefig(fname='./figures/mvn_y_dy_shaded.jpg')
