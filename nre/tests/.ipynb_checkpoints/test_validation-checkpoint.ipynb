# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from nre.preprocess import preprocess_df
from nre.network_connectivity import ConnectivityUnit, ton_iot_conn_param_specs
from nre.analyze_nf_dataset import nre_classification, flow_based_classification
from nre.classification_tools import plot_roc_curves
from nre.validation_tools import validate_method

from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # CIC-IDS-2017

# %%
# CIC-IDS-2017
file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Tuesday-WorkingHours.pcap_ISCX.csv'  # 'Monday-WorkingHours.pcap_ISCX.csv' #  Wednesday-workingHours.pcap_ISCX.csv
#file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv'
#file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv'
#file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Friday-WorkingHours-Morning.pcap_ISCX.csv'
#file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv'
#file_addr = '..\CIC-IDS-2017\GeneratedLabelledFlows\TrafficLabelling\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv'

# NF-ToN-IoT
file_addr = r'..\..\NF-ToN-IoT\NF-ToN-IoT-v3-small.csv'
#file_addr = r'..\..\NF-ToN-IoT\NF-ToN-IoT-v3.csv'

# Definitions
date_col = 'FLOW_START_MILLISECONDS' # 'FLOW_START_MILLISECONDS' # ' Timestamp'
label_col = 'Label' # 'Label' # ' Label'
benign_label = '0'  # '0' # 'BENIGN'
src_id_col = 'IPV4_SRC_ADDR' # ' Source IP'
dst_id_col = 'IPV4_DST_ADDR' # ' Total Backward Packets'
src_feature_col = 'OUT_PKTS' # ' Total Fwd Packets'
dst_feature_col = 'IN_PKTS' # ' Total Backward Packets'
conn_param = 'NPS'
conn_param_specs = ton_iot_conn_param_specs

# %%
#df_cic = pd.read_csv(file_addr, header=0, encoding='cp1252')
df_iot = pd.read_csv(file_addr, sep=',', encoding='utf-8')

#df = preprocess_df(df_cic, date_col=' Timestamp')
df_whole = preprocess_df(df_iot, date_col=date_col)

print(df_whole.shape)
# Out:
# (507190, 55)

# %% [markdown]
# # Train - Test Split
# Use the same split (seed) in experiment section

# %%
seed = 138
test_size = 0.33

ind_co = int(df_whole.shape[0] * (1 - test_size))
df_train, df_test = df_whole.iloc[:ind_co, :], df_whole.iloc[ind_co:, :]

# %%
df_train.shape, df_test.shape
# Out:
# ((339817, 55), (167373, 55))

# %%
np.unique(df_train[label_col].values, return_counts= True)
# Out:
# (array([0, 1], dtype=object), array([199643, 140174], dtype=int64))

# %%
type(df_train[label_col][0])
# Out:
# int

# %% [markdown]
# # Network Scope

# %% [markdown]
# ## CIC-IDS-2017

# %%
with open(r'saves\victim_net.pickle', 'rb') as handle:
    entity_names = pickle.load(handle) 
len(entity_names)
# Out:
# 13

# %%
with open(r'saves\partitioned_nodes_141.pickle', 'rb') as handle: #105
    subnet_names = pickle.load(handle) 
len(subnet_names)
# Out:
# 141

# %% [markdown]
# ## NF-ToN-IoT

# %%
with open(r'saves/ton_iot_small_freq_1000.pickle', 'rb') as handle: #105
    subnet_names = pickle.load(handle) 
entity_names = subnet_names.copy()
len(subnet_names)
# Out:
# 15

# %% [markdown]
# # Validation

# %%
import importlib
import nre.validation_tools

importlib.reload(nre.validation_tools)
from nre.validation_tools import *

# %%
import importlib
import nre.kalman_network_tools

importlib.reload(nre.kalman_network_tools)
from nre.kalman_network_tools import *

# %%
import importlib
import nre.analyze_nf_dataset

importlib.reload(nre.analyze_nf_dataset)
from nre.analyze_nf_dataset import *

# %%
def model_nre(df_train, ml_models, **kwargs):
    return nre_classification(df_train, ml_models, entity_names=subnet_names, standardize=True, **kwargs)  # entity_names=subnet_names

def model_fb(df_train, ml_models, **kwargs):
    return flow_based_classification(df_train, ml_models, entity_names=None, standardize=True, **kwargs)  # entity_names=entity_names

val_size = 0.25
n_train = df_train.shape[0]
n_val = int(n_train * val_size)

df_val = df_train.iloc[n_train-n_val:, :]

# CIC-IDS-2017
"""
param_list = [{'t_graph': 180, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 90, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 45, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 360, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 720, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
               {'t_graph': 180, 'sync_window_size': 0.6, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
               {'t_graph': 180, 'sync_window_size': 0.3, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
               {'t_graph': 180, 'sync_window_size': 2.4, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
               {'t_graph': 180, 'sync_window_size': 4.8, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 180, 'sync_window_size': 1.2, 'forget_factor': 0.2, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 180, 'sync_window_size': 1.2, 'forget_factor': 0.8, 'relief_factor': 0.6, 'k_steps': 1},
              {'t_graph': 180, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 3},
              {'t_graph': 180, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 10}
              ]
"""

# ToN-IoT
okwargs = {'date_col':date_col, 'src_id_col': src_id_col, 'dst_id_col': dst_id_col, 'conn_param':conn_param, 'window_type':'conn',
          'label_col':label_col, 'conn_param_specs':ton_iot_conn_param_specs, 'benign_label': benign_label, 'seed':345, 'verbose':False,
          'labelling_opt': 'majority', 'feat_cols': ('OUT_PKTS', 'IN_PKTS')}
param_list = [{'n_graph': 10_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 8_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 2_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':50, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':25, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':200, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':400, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.2, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.8, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
              {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 3, **okwargs},
              {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 10, **okwargs}
              ]

auc_scores_nre = validate_method(df_train, df_val, model_nre, param_list)
#auc_scores_fb = validate_method(df_train, df_val, model_fb, param_list)
# Out:
#   0%|                                                                                                                                                                                                         | 0/12 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 51
#      34 okwargs = {'date_col':date_col, 'src_id_col': src_id_col, 'dst_id_col': dst_id_col, 'conn_param':conn_param, 'window_type':'conn',
#      35           'label_col':label_col, 'conn_param_specs':ton_iot_conn_param_specs, 'benign_label': benign_label, 'seed':345, 'verbose':False,
#      36           'labelling_opt': 'majority', 'feat_cols': ('OUT_PKTS', 'IN_PKTS')}
#      37 param_list = [{'n_graph': 10_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
#      38               {'n_graph': 8_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
#      39               {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1, **okwargs},
#    (...)
#      48               {'n_graph': 5_000, 'conn_size':100, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 10, **okwargs}
#      49               ]
# ---> 51 auc_scores_nre = validate_method(df_train, df_val, model_nre, param_list)
#      52 #auc_scores_fb = validate_method(df_train, df_val, model_fb, param_list)
#
# File ~\PycharmProjects\NRE\nre\validation_tools.py:20, in validate_method(df_train, df_val, model, param_list)
#      18 roc_curves = {}
#      19 try:
# ---> 20     _ = model(df_train, ml_models, test_df=df_val, roc_curves=roc_curves, **params)
#      21 except AssertionError as e:
#      22     warnings.warn("Assertion Error: \n{}".format(e))
#
# Cell In[11], line 4, in model_nre(df_train, ml_models, **kwargs)
#       3 def model_nre(df_train, ml_models, **kwargs):
# ----> 4     return nre_classification(df_train, ml_models, entity_names=subnet_names, standardize=True, **kwargs)
#
# File ~\PycharmProjects\NRE\nre\analyze_nf_dataset.py:353, in nre_classification(df, models, test_df, standardize, benign_label, roc_curves, test_size, seed, **kwargs)
#     334 def nre_classification(df, models, test_df=None, standardize=False, benign_label='BENIGN', roc_curves=None,
#     335                        test_size=0.33, seed=None, **kwargs):
#     336     """
#     337     Binary classification performance of Network Risk Estimation Method.
#     338
#    (...)
#     351
#     352    """
# --> 353     risk_mat, labels, _, _, _ = get_risk_mat_from_df(df, benign_label=benign_label, **kwargs)
#     354     # print(labels)
#     355     ind = np.array(labels) != 'Empty'
#
# File ~\PycharmProjects\NRE\nre\kalman_network_tools.py:409, in get_risk_mat_from_df(df, forget_factor, k_steps, relief_factor, return_cov, return_datetimes, timeit, **kwargs)
#     382 def get_risk_mat_from_df(df, forget_factor=0.5, k_steps=1, relief_factor=0.2, return_cov=False, return_datetimes=False,
#     383                          timeit=False, **kwargs):
#     384     """
#     385     Returns the entity risks obtained from windowed ConnectivityUnit
#     386
#    (...)
#     406         t_sim: (Returned only if timeit==True) List of running time spent for calculating each graph
#     407     """
# --> 409     out_vars = parse_df_2_state_graphs(df, return_datetimes=return_datetimes, timeit=timeit, **kwargs)
#     410     out_vars = list(out_vars)
#     412     all_graphs, labels, label_counts, entity_names = out_vars[:4]  # First 4 are always same
#
# File ~\PycharmProjects\NRE\nre\kalman_network_tools.py:336, in parse_df_2_state_graphs(df, entity_names, method, window_type, t_graph, time_scale, n_graph, date_col, label_col, src_id_col, dst_id_col, labelling_opt, benign_label, conn_param_specs, skip_idle, verbose, return_datetimes, timeit, **kwargs)
#     333 delta_datetime = datetime.timedelta(minutes=t_graph) if time_scale == 'min' else datetime.timedelta(
#     334     seconds=t_graph)
#     335 window_last_datetime = temp_df[date_col].iloc[0] + delta_datetime
# --> 336 cu.read_flows(temp_df, entity_names=entity_names, last_datetime=window_last_datetime, window_type=window_type,
#     337               date_col=date_col, time_scale=time_scale, src_id_col=src_id_col, dst_id_col=dst_id_col, **kwargs)
#     338 if verbose:
#     339     print('Current time and samples shape: ', current_datetime, cu.samples.shape)
#
# TypeError: ConnectivityUnit.read_flows() got an unexpected keyword argument 'feat_cols'

# %%
auc_scores_nre

# %%
auc_scores_fb
# Out:
# [({'n_graph': 10000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 8000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0.8888888888888888),
#  ({'n_graph': 5000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 2000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0.5955882352941176),
#  ({'n_graph': 5000,
#    'conn_size': 50,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 25,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 200,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 400,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 100,
#    'forget_factor': 0.2,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 100,
#    'forget_factor': 0.8,
#    'relief_factor': 0.6,
#    'k_steps': 1,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 3,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0),
#  ({'n_graph': 5000,
#    'conn_size': 100,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 10,
#    'date_col': 'FLOW_START_MILLISECONDS',
#    'src_id_col': 'IPV4_SRC_ADDR',
#    'dst_id_col': 'IPV4_DST_ADDR',
#    'conn_param': 'NPS',
#    'window_type': 'conn',
#    'label_col': 'Label',
#    'conn_param_specs': {'Activation': {'method': 'activation'},
#     'Bytes Sent': {'method': 'total',
#      'src_feature_col': 'OUT_BYTES',
#      'dst_feature_col': 'IN_BYTES'},
#     'Bytes Received': {'method': 'total',
#      'src_feature_col': 'IN_BYTES',
#      'dst_feature_col': 'OUT_BYTES'},
#     'Flow Duration': {'method': 'total',
#      'src_feature_col': 'FLOW_DURATION_MILLISECONDS',
#      'dst_feature_col': 'FLOW_DURATION_MILLISECONDS'},
#     'NPS': {'method': 'total',
#      'src_feature_col': 'OUT_PKTS',
#      'dst_feature_col': 'IN_PKTS'},
#     'NPR': {'method': 'total',
#      'src_feature_col': 'IN_PKTS',
#      'dst_feature_col': 'OUT_PKTS'},
#     'Port Number': {'method': 'mode',
#      'src_feature_col': 'L4_SRC_PORT',
#      'dst_feature_col': 'L4_DST_PORT'},
#     'Protocol': {'method': 'mode',
#      'src_feature_col': 'PROTOCOL',
#      'dst_feature_col': 'PROTOCOL'},
#     'Throughput': {'method': 'average',
#      'src_feature_col': 'SRC_TO_DST_AVG_THROUGHPUT',
#      'dst_feature_col': 'DST_TO_SRC_AVG_THROUGHPUT'},
#     'Retransmitted Packets': {'method': 'total',
#      'src_feature_col': 'RETRANSMITTED_IN_PKTS',
#      'dst_feature_col': 'RETRANSMITTED_OUT_PKTS'},
#     'Response Time': {'method': 'average',
#      'src_feature_col': 'DST_TO_SRC_IAT_AVG',
#      'dst_feature_col': 'SRC_TO_DST_IAT_AVG'}},
#    'benign_label': '0',
#    'seed': 345,
#    'verbose': False,
#    'labelling_opt': 'majority',
#    'feat_cols': ('OUT_PKTS', 'IN_PKTS')},
#   0)]

# %%
np.where(df_train[label_col] == 1)
# Out:
# (array([     1,      2,      3, ..., 339798, 339799, 339805], dtype=int64),)

# %%
res = (auc_scores_nre, auc_scores_fb)
with open(r'saves\validation_curves_141.pickle', 'wb') as handle:
    pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
res = (auc_scores_nre, auc_scores_fb)
with open(r'saves\validation_curves_iot_15.pickle', 'wb') as handle:
    pickle.dump(res, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(r'saves\validation_curves_iot_15.pickle', 'rb') as handle:
    auc_scores_nre, auc_scores_fb = pickle.load(handle)

# %%
auc_scores_nre
# Out:
# [({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.9333333333333333),
#  ({'t_graph': 90,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.9541666666666667),
#  ({'t_graph': 45,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.996011964107677),
#  ({'t_graph': 360,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.8636363636363636),
#  ({'t_graph': 720,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.8333333333333334),
#  ({'t_graph': 180,
#    'sync_window_size': 0.6,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.942857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 0.3,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.942857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 2.4,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.9333333333333333),
#  ({'t_graph': 180,
#    'sync_window_size': 4.8,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.9333333333333333),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.2,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   1.0),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.8,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.8761904761904762),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 3},
#   0.9238095238095239),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 10},
#   0.9238095238095239)]

# %%
auc_scores_fb
# Out:
# [({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 90,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.6625000000000001),
#  ({'t_graph': 45,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.576271186440678),
#  ({'t_graph': 360,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7727272727272727),
#  ({'t_graph': 720,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.6666666666666666),
#  ({'t_graph': 180,
#    'sync_window_size': 0.6,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 0.3,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 2.4,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 4.8,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.2,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.8,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 3},
#   0.7142857142857143),
#  ({'t_graph': 180,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 10},
#   0.7142857142857143)]

# %%
param_list = [{'t_graph': 90, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1}]
auc_scores_nre = validate_model(df_train, df_val, model_nre, param_list)
auc_scores_nre
# Out:
#   0%|                                                                                                                          | 0/1 [00:00<?, ?it/s]C:\Users\bayer\PycharmProjects\NRE\venv2\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:23<00:00, 83.35s/it]
# [({'t_graph': 90,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.9541666666666667)]

# %%
param_list = [{'t_graph': 360, 'sync_window_size': 1.2, 'forget_factor': 0.5, 'relief_factor': 0.6, 'k_steps': 1}]
auc_scores_fb = validate_model(df_train, df_val, model_fb, param_list)
auc_scores_fb
# Out:
#   0%|                                                                                                                          | 0/1 [00:00<?, ?it/s]C:\Users\bayer\PycharmProjects\NRE\venv2\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.56s/it]
# [({'t_graph': 360,
#    'sync_window_size': 1.2,
#    'forget_factor': 0.5,
#    'relief_factor': 0.6,
#    'k_steps': 1},
#   0.7727272727272727)]
